# %% [markdown]
# # 3. Descriptive Statistics - Measures of Central Tendency and variability

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data.csv")
df
# Out:
#       id groups  age  healthy_eating  active_lifestyle  salary
# 0      0      A   36               5                 5    2297
# 1      1      A   55               3                 5    1134
# 2      2      A   61               8                 1    4969
# 3      3      O   29               3                 6     902
# 4      4      O   34               6                 2    3574
# ..   ...    ...  ...             ...               ...     ...
# 995  995      O   33               7                 7    2996
# 996  996      O   21               1                 2     667
# 997  997      O   49               9                 7    4158
# 998  998     AB   56               6                 7    2414
# 999  999      B   64               4                 9     788
#
# [1000 rows x 6 columns]

# %%
df.describe()
# Out:
#                 id          age  healthy_eating  active_lifestyle      salary
# count  1000.000000  1000.000000     1000.000000       1000.000000  1000.00000
# mean    499.500000    41.155000        4.944000          5.683000  2227.46100
# std     288.819436    13.462995        2.013186          2.048587  1080.20976
# min       0.000000    18.000000        0.000000          0.000000   553.00000
# 25%     249.750000    30.000000        4.000000          4.000000  1360.00000
# 50%     499.500000    41.000000        5.000000          6.000000  2174.00000
# 75%     749.250000    53.000000        6.000000          7.000000  2993.75000
# max     999.000000    64.000000       10.000000         10.000000  5550.00000

# %%
# grouped_df = df.groupby('age')['salary'].agg(['mean', 'median', 'max', 'min', 'std'])
# grouped_df
# Out:
#             mean  median   max   min          std
# age
# 18   2040.560000  1601.0  4505   779  1130.062391
# 19   2497.590909  2471.5  4508   785   877.927845
# 20   2158.941176  1833.0  4041   779  1115.664402
# 21   2006.300000  2006.5  4041   553  1019.559353
# 22   2453.100000  2355.5  5318   902  1134.438878
# 23   2554.277778  2412.5  5086   553  1265.685529
# 24   2507.312500  2587.5  4387   902   922.163956
# 25   2402.272727  2586.0  4390   553  1103.680345
# 26   2479.263158  2529.0  5435   785  1245.530803
# 27   2041.266667  1948.0  3923  1020   884.243621
# 28   2399.153846  2587.5  4155   902  1029.308688
# 29   2211.052632  2065.0  4038   670   982.027238
# 30   2204.103448  1716.0  5435   553  1356.844484
# 31   1892.652174  1833.0  4969   785   937.131678
# 32   2630.333333  2937.0  4969   779  1219.773702
# 33   2472.925926  2297.0  5086   902  1153.670594
# 34   2025.333333  1890.5  3574   670   914.147627
# 35   2485.571429  2065.0  4508   553  1350.028650
# ...

# %%
grouped_df2 = df.groupby('groups')['salary'].agg(['mean', 'median', 'max', 'min', 'std'])
grouped_df2
# Out:
#                mean  median   max  min          std
# groups
# A       2176.221333  2065.0  5435  553  1037.818981
# AB      2261.688000  2065.0  5435  553  1189.918352
# B       2232.776000  2174.0  5550  553  1171.430177
# O       2265.520000  2182.0  5435  553  1053.963616

# %%
from seaborn import load_dataset

# %%
df_iris = load_dataset('iris')
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_iris.groupby('species').describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
df_iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
setosa_data = df_iris[df_iris['species'] == 'setosa']
versicolor_data = df_iris[df_iris['species'] == 'versicolor']
virginica_data = df_iris[df_iris['species'] == 'virginica']

# %%
setosa_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
versicolor_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
virginica_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000
